# %%
import unittest
import sys
import os

# Add the current directory to sys.path
sys.path.insert(0, os.path.abspath(os.path.dirname(__file__)))

from app import app  # Ensure 'app.py' is in the same folder

class FlaskTestCase(unittest.TestCase):
    def test_home(self):
        tester = app.test_client(self)
        response = tester.get('/')
        self.assertEqual(response.status_code, 200)

if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ======================================================================
# ERROR: C:\Users\DELL\AppData\Roaming\jupyter\runtime\kernel-9a427b3c-b661-41fc-9101-9597e181d808 (unittest.loader._FailedTest.C:\Users\DELL\AppData\Roaming\jupyter\runtime\kernel-9a427b3c-b661-41fc-9101-9597e181d808)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute 'C:\Users\DELL\AppData\Roaming\jupyter\runtime\kernel-9a427b3c-b661-41fc-9101-9597e181d808'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# C:\Users\DELL\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3513: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
